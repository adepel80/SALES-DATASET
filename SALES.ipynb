# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\user'

# %%
sales = pd.read_csv("salesdata.csv")

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description item_price
# 0                                         [Clementine]     $3.39
# 1                                              [Apple]     $3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
sales.info
# Out:
# <bound method DataFrame.info of      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description item_price
# 0                                         [Clementine]     $3.39
# 1                                              [Apple]     $3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# ...

# %%
pd.set_option("display.max_column",sales.shape[-1])

# %%
sales.head()
# Out:
#    order_id  quantity         item_name  \
# 0         1         1              Izze
# 1         1         1  Nantucket Nectar
# 2         2         2      Chicken Bowl
# 3         3         1      Chicken Bowl
# 4         4         1     Steak Burrito
#
#                                   choice_description item_price
# 0                                       [Clementine]     $3.39
# 1                                            [Apple]     $3.39
# 2  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 3  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 4  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75

# %%
sales["item_price"].unique()
# Out:
# array(['$3.39 ', '$16.98 ', '$10.98 ', '$11.75 ', '$9.25 ', '$8.75 ',
#        '$11.25 ', '$8.49 ', '$2.18 ', '$8.99 ', '$1.09 ', '$22.50 ',
#        '$11.48 ', '$17.98 ', '$17.50 ', '$1.25 '], dtype=object)

# %%
sales.isna().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# dtype: int64

# %%
for x in sales['quantity']:
    if x > 1:
        print(x)
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %%
sales["item_price"].unique()
# Out:
# array(['$3.39 ', '$16.98 ', '$10.98 ', '$11.75 ', '$9.25 ', '$8.75 ',
#        '$11.25 ', '$8.49 ', '$2.18 ', '$8.99 ', '$1.09 ', '$22.50 ',
#        '$11.48 ', '$17.98 ', '$17.50 ', '$1.25 '], dtype=object)

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description item_price
# 0                                         [Clementine]     $3.39
# 1                                              [Apple]     $3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %% [markdown]
# ### REMOVE THE DOLLAR SIGN $ CALCULATE THE >,< OR = OF THE PRODUCTS

# %%
sales['item_price'] = sales['item_price'].replace('''[$,]''', '', regex = True).astype(float)

# %%
sales['item_price']
# Out:
# 0       3.39
# 1       3.39
# 2      16.98
# 3      10.98
# 4      11.75
#        ...
# 195     8.99
# 196     9.25
# 197     8.99
# 198     8.49
# 199     8.49
# Name: item_price, Length: 200, dtype: float64

# %% [markdown]
# ### CALCULATE PRODUCTS GREATER THAN 10

# %%
for x in sales['item_price']:
    if x > 10:
        print(x)
# Out:
# 16.98
# 10.98
# 11.75
# 11.25
# 10.98
# 11.75
# 11.25
# 11.75
# 10.98
# 10.98
# 11.25
# 11.75
# 11.25
# 10.98
# 11.25
# 11.75
# 11.75
# 11.75
# 11.75
# 11.25
# 11.75
# 10.98
# 22.5
# 11.75
# 11.25
# 11.25
# 11.25
# 11.25
# 11.75
# 11.48
# 17.98
# 17.5
# 17.5
# 11.25
# 11.75
# 10.98
# 10.98
# 11.48
# 11.25
# 11.75
# 10.98
# 11.48
# 11.25
# 11.48
# 11.25
# 10.98
# 11.25
# 11.25
# 11.25
# 11.25
# 22.5
# 11.75
# 17.5
# 11.25
# 11.75
# 11.75
# 17.5
# 10.98
# 10.98
# 11.75

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
len(sales[sales["item_price"] > 10])
# Out:
# 60

# %%
sales[sales["item_price"] > 10].count()
# Out:
# order_id              60
# quantity              60
# item_name             60
# choice_description    60
# item_price            60
# dtype: int64

# %% [markdown]
# ### CALCULATE PRODUCTS LESSER THAN OR EQUALS TO 10

# %%
for x in sales['item_price']:
    if x <= 10:
        print(x)
# Out:
# 3.39
# 3.39
# 9.25
# 9.25
# 8.75
# 8.75
# 8.49
# 8.49
# 2.18
# 8.75
# 8.99
# 3.39
# 3.39
# 8.49
# 8.99
# 1.09
# 8.49
# 8.99
# 8.99
# 8.75
# 8.75
# 8.75
# 8.99
# 3.39
# 8.99
# 8.99
# 2.18
# 1.09
# 8.99
# 9.25
# 9.25
# 8.75
# 8.99
# 8.99
# 3.39
# 8.99
# 8.99
# 8.99
# 8.75
# 8.75
# 8.75
# 8.75
# 9.25
# 8.75
# 8.75
# 9.25
# 8.49
# 8.99
# 9.25
# 9.25
# 9.25
# 8.75
# 8.75
# 8.99
# 8.99
# 8.49
# 3.39
# 8.99
# 1.09
# 9.25
# 8.75
# 8.49
# 8.99
# 8.49
# 1.09
# 8.99
# 8.75
# 9.25
# 8.99
# 1.09
# 9.25
# 8.49
# 9.25
# 8.49
# 8.49
# 2.18
# 8.49
# 8.75
# 8.49
# 2.18
# 8.49
# 3.39
# 8.49
# 8.99
# 8.49
# 1.09
# 1.09
# 9.25
# 8.75
# 9.25
# 8.49
# 8.49
# 8.99
# 8.75
# 1.09
# 8.99
# 8.49
# 1.09
# 8.75
# 8.49
# 3.39
# 8.75
# 9.25
# 8.75
# 8.75
# 9.25
# 8.75
# 9.25
# 8.75
# 8.99
# 1.09
# 8.99
# 8.75
# 9.25
# 9.25
# 9.25
# 8.75
# 9.25
# 8.99
# 1.09
# 1.09
# 1.09
# 8.99
# 1.09
# 8.75
# 8.75
# 9.25
# 9.25
# 8.75
# 8.75
# 8.99
# 8.99
# 8.99
# 1.09
# 1.25
# 8.99
# 9.25
# 8.99
# 8.49
# 8.49

# %%
len(sales[sales["item_price"] <= 10])
# Out:
# 140

# %% [markdown]
# ### GROUP 2

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
pd.crosstab(sales['item_name'],sales['item_price'])
# Out:
# item_price             1.09   1.25   ...  17.98  22.50
# item_name                            ...
# Barbacoa Bowl              0      0  ...      0      0
# Barbacoa Burrito           0      0  ...      0      0
# Barbacoa Crispy Tacos      0      0  ...      0      0
# Barbacoa Soft Tacos        0      0  ...      0      0
# Canned Soda               15      0  ...      0      0
# Canned Soft Drink          0      1  ...      0      0
# Carnitas Bowl              0      0  ...      0      0
# Carnitas Burrito           0      0  ...      0      0
# Carnitas Soft Tacos        0      0  ...      0      0
# Chicken Bowl               0      0  ...      0      0
# Chicken Burrito            0      0  ...      0      0
# Chicken Crispy Tacos       0      0  ...      0      0
# Chicken Salad              0      0  ...      0      0
# Chicken Salad Bowl         0      0  ...      0      2
# Chicken Soft Tacos         0      0  ...      0      0
# ...

# %%
sales['item_price'] == sales['item_name'].count()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: item_price, Length: 200, dtype: bool

# %% [markdown]
# ### GROUP 3 CALCULATE THE QUANTITY OF THE MOST EXPENSIVE ITEMS ORDERED

# %%
sales[sales['item_price'] == sales['item_price'].max()]
# Out:
#      order_id  quantity           item_name  \
# 94         60         2  Chicken Salad Bowl
# 153        94         2  Chicken Salad Bowl
#
#                                     choice_description  item_price
# 94   [Tomatillo Green Chili Salsa, [Sour Cream, Che...        22.5
# 153  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        22.5

# %% [markdown]
# ### CALCULATE HOW MANY TIMES WAS CHICKEN BURRITO ORDERED

# %%
len(sales[sales['item_name'] == 'Chicken Burrito'])
# Out:
# 39

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %% [markdown]
# ### CALCULATE HOW MANY TIMES DID SOMEONE ORDER MORE THAN ONE CANNED SODA

# %%
len(sales[(sales['item_name'] == 'Canned Soda') & (sales['quantity']>1)])
# Out:
# 4

# %% [markdown]
# ### CALCULATE HOW MANY TIMES DID SOMEONE ORDER CANNED SODA

# %%
len(sales[sales['item_name'] == 'Canned Soda'])
# Out:
# 19

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %% [markdown]
# ### GROUP 2, SORTING THE PRODUCT BY PRICE

# %%
sales.get(['item_price', 'item_name'])
# Out:
#      item_price            item_name
# 0          3.39                 Izze
# 1          3.39     Nantucket Nectar
# 2         16.98         Chicken Bowl
# 3         10.98         Chicken Bowl
# 4         11.75        Steak Burrito
# ..          ...                  ...
# 195        8.99        Steak Burrito
# 196        9.25     Steak Soft Tacos
# 197        8.99  Barbacoa Soft Tacos
# 198        8.49      Chicken Burrito
# 199        8.49      Chicken Burrito
#
# [200 rows x 2 columns]

# %% [markdown]
# ### GROUP 2 SORTING THE PRODUCT BY THE ITEM NAME

# %%
sales.get(['item_name', 'choice_description'])
# Out:
#                item_name                                 choice_description
# 0                   Izze                                       [Clementine]
# 1       Nantucket Nectar                                            [Apple]
# 2           Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 3           Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 4          Steak Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# ..                   ...                                                ...
# 195        Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Black Bea...
# 196     Steak Soft Tacos      [Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]
# 197  Barbacoa Soft Tacos  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...
# 198      Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# 199      Chicken Burrito  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...
#
# [200 rows x 2 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
sales['item_price'].plot()
# Out:
# <AxesSubplot:>

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
sales.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
